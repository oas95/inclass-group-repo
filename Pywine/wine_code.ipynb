# %%
#Dependencies
import pandas as pd

wine_data_load = "Data/winemag-data-130k-v2.csv"

wine_data = pd.read_csv(wine_data_load)

wine_data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# Out:
# str

# %%
#Getting Wine summary per country
total_countries = len(wine_data.country.unique())

country_summary = wine_data.groupby(['country'])

country_names = wine_data.country.sort_values().unique()

mean_points = wine_data.points.mean()

mean_price = wine_data.price.mean()

total_reviewers = len(wine_data.taster_name.unique())

meanprice_country = list(country_summary.price.mean())

#meanscore_country_df = wine_data()

# %%
country_summary_df = pd.DataFrame({"Country": country_names,
"Average Price": meanprice_country})

country_summary_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27524\3376197209.py in <module>
#       1 country_summary_df = pd.DataFrame({"Country": country_names,
# ----> 2 "Average Price": meanprice_country})
#       3
#       4 country_summary_df
#
# c:\Users\gbnlo\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# c:\Users\gbnlo\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
# ...
